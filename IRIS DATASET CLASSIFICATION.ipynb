# %% [markdown]
# # IRIS DATASET CLASSIFICATION
#
# Here Logistic Regression model as well as support vecctor classification model is used to classify the flowers into three categories i.e, setosa, versicolor, virginica using the sepal width, sepal length, petal width and petal length.

# %% [markdown]
# # Reading the dataset

# %%
import pandas as pd

df = pd.read_csv("C:/Users/aruna/Downloads/iris.txt")
df
# Out:
#      sepal length(cm)  sepal width(cm)  petal length(cm)  petal width(cm)  \
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %% [markdown]
# # Checking for missing values

# %%
df.isnull().sum()
# Out:
# sepal length(cm)    0
# sepal width(cm)     0
# petal length(cm)    0
# petal width(cm)     0
# class               0
# dtype: int64

# %% [markdown]
# #There are no missing values

# %%
df.describe()
# Out:
#        sepal length(cm)  sepal width(cm)  petal length(cm)  petal width(cm)
# count        150.000000       150.000000        150.000000       150.000000
# mean           5.843333         3.054000          3.758667         1.198667
# std            0.828066         0.433594          1.764420         0.763161
# min            4.300000         2.000000          1.000000         0.100000
# 25%            5.100000         2.800000          1.600000         0.300000
# 50%            5.800000         3.000000          4.350000         1.300000
# 75%            6.400000         3.300000          5.100000         1.800000
# max            7.900000         4.400000          6.900000         2.500000

# %% [markdown]
# # Checking for outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df , orient = 'h')
plt.show()

# %% [markdown]
# There are ouliers present in sepal width. It can probably tell us about the plants with larger sepal width or there can be mistake in taking measuremnts

# %% [markdown]
# # Split the dataset into features and target
#
# The dataset is split into two i.e, features and target. Here sepal length and width , petal length and width will be the features.

# %%
X = df.drop('class', axis=1)
Y = df['class']

# %%
X
# Out:
#      sepal length(cm)  sepal width(cm)  petal length(cm)  petal width(cm)
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
# [150 rows x 4 columns]

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object

# %% [markdown]
# # Train - Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, random_state = 0)

# %% [markdown]
# # Choosing models
#
# Here Logistic Regression as well as Support Vector Classification models are used. Since classification is the main task here Classification algorithms are the best.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %% [markdown]
# # Model training and prediction

# %%
# Logistic Regression model


lr_model = LogisticRegression(max_iter= 1000)
lr_model.fit(X_train,Y_train)
lr_pred = lr_model.predict(X_test)

# %%
# SVC model to implement SVM

svm_model = SVC()
svm_model.fit(X_train, Y_train)
svm_pred = svm_model.predict(X_test)

# %%
# Logistic Regression models prediction

lr_df = pd.DataFrame({ 'Actual': Y_test, 'Predicted': lr_pred})
lr_df
# Out:
#               Actual        Predicted
# 114   Iris-virginica   Iris-virginica
# 62   Iris-versicolor  Iris-versicolor
# 33       Iris-setosa      Iris-setosa
# 107   Iris-virginica   Iris-virginica
# 7        Iris-setosa      Iris-setosa
# 100   Iris-virginica   Iris-virginica
# 40       Iris-setosa      Iris-setosa
# 86   Iris-versicolor  Iris-versicolor
# 76   Iris-versicolor  Iris-versicolor
# 71   Iris-versicolor  Iris-versicolor
# 134   Iris-virginica   Iris-virginica
# 51   Iris-versicolor  Iris-versicolor
# 73   Iris-versicolor  Iris-versicolor
# 54   Iris-versicolor  Iris-versicolor
# 63   Iris-versicolor  Iris-versicolor
# 37       Iris-setosa      Iris-setosa
# 78   Iris-versicolor  Iris-versicolor
# 90   Iris-versicolor  Iris-versicolor
# 45       Iris-setosa      Iris-setosa
# 16       Iris-setosa      Iris-setosa
# 121   Iris-virginica   Iris-virginica
# 66   Iris-versicolor  Iris-versicolor
# 24       Iris-setosa      Iris-setosa
# 8        Iris-setosa      Iris-setosa
# ...

# %%
# SVC models prediction

svm_df = pd.DataFrame({ 'Actual': Y_test, 'Predicted': svm_pred})
svm_df
# Out:
#               Actual        Predicted
# 114   Iris-virginica   Iris-virginica
# 62   Iris-versicolor  Iris-versicolor
# 33       Iris-setosa      Iris-setosa
# 107   Iris-virginica   Iris-virginica
# 7        Iris-setosa      Iris-setosa
# 100   Iris-virginica   Iris-virginica
# 40       Iris-setosa      Iris-setosa
# 86   Iris-versicolor  Iris-versicolor
# 76   Iris-versicolor  Iris-versicolor
# 71   Iris-versicolor  Iris-versicolor
# 134   Iris-virginica   Iris-virginica
# 51   Iris-versicolor  Iris-versicolor
# 73   Iris-versicolor  Iris-versicolor
# 54   Iris-versicolor  Iris-versicolor
# 63   Iris-versicolor  Iris-versicolor
# 37       Iris-setosa      Iris-setosa
# 78   Iris-versicolor  Iris-versicolor
# 90   Iris-versicolor  Iris-versicolor
# 45       Iris-setosa      Iris-setosa
# 16       Iris-setosa      Iris-setosa
# 121   Iris-virginica   Iris-virginica
# 66   Iris-versicolor  Iris-versicolor
# 24       Iris-setosa      Iris-setosa
# 8        Iris-setosa      Iris-setosa
# ...

# %% [markdown]
# # Accuracy of the models

# %%
from sklearn.metrics import accuracy_score, classification_report

lr_accuracy = accuracy_score(Y_test, lr_pred)
lr_report= classification_report(Y_test, lr_pred, target_names=['Iris-setosa','Iris-versicolor','Iris-virginica'])

# %%
lr_accuracy   #Logistic Regression models Accuracy
# Out:
# 1.0

# %%
lr_report
# Out:
# '                 precision    recall  f1-score   support\n\n    Iris-setosa       1.00      1.00      1.00        11\nIris-versicolor       1.00      1.00      1.00        13\n Iris-virginica       1.00      1.00      1.00         6\n\n       accuracy                           1.00        30\n      macro avg       1.00      1.00      1.00        30\n   weighted avg       1.00      1.00      1.00        30\n'

# %%
svm_accuracy = accuracy_score(Y_test, svm_pred)
svm_report= classification_report(Y_test, svm_pred)

# %%
svm_accuracy        #SVM models Accuracy
# Out:
# 1.0

# %%
svm_report
# Out:
# '                 precision    recall  f1-score   support\n\n    Iris-setosa       1.00      1.00      1.00        11\nIris-versicolor       1.00      1.00      1.00        13\n Iris-virginica       1.00      1.00      1.00         6\n\n       accuracy                           1.00        30\n      macro avg       1.00      1.00      1.00        30\n   weighted avg       1.00      1.00      1.00        30\n'

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, class_names, title):
    cm = confusion_matrix(y_true, y_pred)
    cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# Plot confusion matrix for Logistic Regression
plot_confusion_matrix(Y_test, lr_pred,['Iris-setosa','Iris-versicolor','Iris-virginica'] , title='Logistic Regression Confusion Matrix')

# Plot confusion matrix for SVM
plot_confusion_matrix(Y_test, svm_pred,['Iris-setosa','Iris-versicolor','Iris-virginica'] , title='Support Vector Machine Confusion Matrix')

# %% [markdown]
# # Conclusion
#
#
# We got 100% accuracy for both models. But when the size of the test set is increased, accuracy is reduced. So, at these times SVM performs better than Logistic Regression model.
#
#
# SVC is better than Logistic Regression model.
#
# When the test_size is increased that is to 0.40, the accuracy of lr_ model is 0.916666 and the accuracy of svm_model is 0.93333.
